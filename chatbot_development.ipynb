# %% [markdown]
# # Chatbot Development
#
# Use this notebook to load the model and then initialize, update, and test the chatbot.

# %% [markdown]
# ### Setup and Imports

# %%
import torch
from huggingface_hub import login


from src.chat import Chatbot
from config import BASE_MODEL, MY_MODEL

# %%
"""
TODO: Add your Hugging Face token
Options:
1. Use login() and enter token when prompted. It won't ask for your token if you already logged in using the command: huggingface-cli login in the terminal.
2. Set environment variable HUGGINGFACE_TOKEN
3. Pass token directly (not recommended for shared notebooks)
"""

login()

# %% [markdown]
# ### Initialize and test chatbot

# %%
"""
Create chatbot instance using chat.py
"""
chatbot = Chatbot()

# %%
"""
Test out generating some responses from the chatbot.
Inference time
"""
test_question = "I’m a 6-3 junior who needs a CI-H, \
                prefers afternoon classes, and am interested in AI ethics. What options are available for someone in my situation?"

print(f"\nQuestion: {test_question}")
response = chatbot.get_response(test_question)
print(f"Response: {response}")
# Out:
# Question: I’m a 6-3 junior who needs a CI-H,                 prefers afternoon classes, and am interested in AI ethics. What options are available for someone in my situation?
# Response: I'd be happy to help you find a CI-H course that fits your schedule and interests.
#
# As a 6-3 junior, you have a number of constraints to consider when selecting a course. Let me check the MIT Course Catalog for you.
#
# After searching the catalog, I found a few courses that may be of interest to you:
#
# 1. **6.036 Introduction to Machine Learning** (CI-H, HASS, REST): This course explores the fundamentals of machine learning, including supervised and unsupervised learning, regression, classification, clustering, and neural networks. It's offered by the Electrical Engineering and Computer Science (EECS) department, and has a lecture schedule that fits your afternoon preferences.
#
# Instructor: Multiple instructors, varies by semester
#  Class Format: Lecture and discussion
#  Schedule: 2:00-3:00 PM (check the course website for more information)
#
# 2. **STS.420 Science, Technology, and Society: AI and Ethics** (CI-H, HASS, REST): This course explores the social, cultural, and historical contexts of technological innovation, with a focus on AI and its implications for society. It's offered by the Science, Technology, and Society (STS) department, and has a lecture schedule that fits your afternoon preferences.
#
# Instructor: Dr. Caitlin Ring Klein
#  Class Format: Lecture and discussion
#  Schedule: 2:00-3:00 PM (check the course website for more information)
#
# 3. **15.492 Introduction to Artificial Intelligence and Machine Learning** (CI-H, HASS, REST): This course provides an introduction to the field of artificial intelligence and machine learning, covering topics such as neural networks, decision trees, and reinforcement learning. It's offered by the Electrical Engineering and Computer Science (EECS) department, and has a lecture schedule that fits your afternoon preferences.
#
# Instructor: Multiple instructors, varies by semester
#  Class Format: Lecture and discussion
#  Schedule: 2:00-3:00 PM (check the course website for more information)
#
# These courses meet your requirements for a CI-H, are offered in the afternoon, and cover topics related to AI ethics. However, please note that course offerings and schedules are subject to change, so be sure to check the course websites for the most up-to-date information.
#
# I hope this helps! Do any of these courses stand out to you, or would you like me to search for more options?

# %% [markdown]
# # TODO: Update pre-trained Llama to be a task-specific chatbot
#
# This part is up to you! You might want to finetune the model, simply make a really good system prompt, use RAG, provide the model relevant data in-context, etc. Be creative!
#
# You can also feel free to do this in another script and then evaluate the model here.
#
# Tips:
# - HuggingFace has built-in methods to finetune models, if you choose that route. Take advantage of those methods! You can then save your new, finetuned model in the HuggingFace Hub. Change MY_MODEL in config.py to the name of the model in the hub to make your chatbot use it.
# - You may also want to consider LoRA if you choose finetuning.
